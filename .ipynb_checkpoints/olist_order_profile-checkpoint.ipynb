# %% [markdown]
# # Order Profile Analysis
# GitHub location: https://github.com/LarsTinnefeld/Olist-order-profile-analysis
#
# **A project of the Olist ecommerce business analysis.**
#
# <img src="https://i2.wp.com/dataneophyte.com/wp-content/uploads/2019/12/Logo-01.png" width="400" height="300">
#
#
# ## Questions to answer
# 1. What conclusions can we draw from order- and SKU-profile?
# 2. Impacts of Olist's business model on inventory and fullfillment process
# 3. Can we predict buying behaviour between articles (association)?
#
# ## Table of Contents
#
# I. [Data Import and Wrangling](#data)<br>
# II. [Exploratory Date Analysis](#eda)<br>
# III. [Order and SKU profile](#profile)<br>
# IV. [Affinity Analysis](#tbd)<br>
# V. [Evaluation](#evaluation)<br>
# VI. [Conclusion](#conclusion)

# %% [markdown]
# ---
# ## <a class="anchor" id="data">I. Data Import and Wrangling</a>
#
# ### 1. Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
from datetime import datetime as dt
# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# ### 2. Importing data
# Part of the data was inherited from the initial Olist data analysis.
#
# Data structure:

# %% [markdown]
# <img src="https://i.imgur.com/HRhd2Y0.png" width="700" height="450">

# %%
# Importing consolidated order data table
df_orders_consolidated = pd.read_csv('df_orders_consolidated.csv')

# %%
# Refresher
df_orders_consolidated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102422 entries, 0 to 102421
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     102422 non-null  int64
#  1   order_id                       102422 non-null  object
#  2   customer_id                    102422 non-null  object
#  3   order_status                   102422 non-null  object
#  4   order_purchase_timestamp       102422 non-null  object
#  5   order_approved_at              102408 non-null  object
#  6   order_delivered_carrier_date   101395 non-null  object
#  7   order_delivered_customer_date  102422 non-null  object
#  8   order_estimated_delivery_date  102422 non-null  object
#  9   date_ordinal                   102422 non-null  int64
#  10  shipping_time_delta            102422 non-null  int64
#  11  shipping_duration              102422 non-null  int64
#  12  estimated_duration             102422 non-null  int64
#  13  product_id                     102422 non-null  object
#  14  qty                            102422 non-null  int64
#  15  seller_id                      102422 non-null  object
#  16  shipping_limit_date            102422 non-null  object
#  17  price                          102422 non-null  float64
#  18  freight_value                  102422 non-null  float64
#  19  product_category_name          100962 non-null  object
#  20  product_name_lenght            100962 non-null  float64
#  21  product_description_lenght     100962 non-null  float64
#  22  product_photos_qty             100962 non-null  float64
#  23  product_weight_g               102422 non-null  float64
#  24  product_length_cm              102422 non-null  float64
#  25  product_height_cm              102422 non-null  float64
#  26  product_width_cm               102422 non-null  float64
#  27  order_line_cube_in_ltr         102422 non-null  float64
#  28  price_round                    102422 non-null  float64
# dtypes: float64(11), int64(6), object(12)
# memory usage: 22.7+ MB

# %% [markdown]
# Potentially still need to fill gaps for some of the dates if we need these features.
#
# Need to convert dates, function:

# %%
def convert_to_dt(dat, cols):
    '''
    Function takes in a dataframe name and date columns for conversion into datetime format
    
    Inputs
    - dat (data frame)
    - cols (name of columns)

    Outputs
    - None (converts datetime columns)

    '''
    for col in cols:
        dat[col] = pd.to_datetime(dat[col], format='%Y-%m-%d').dt.date

# %%
convert_to_dt(df_orders_consolidated, [
    'order_purchase_timestamp',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
    ])

# %%
df_orders_consolidated.head()
# Out:
#    Unnamed: 0                          order_id  \
# 0           0  bfbd0f9bdef84302105ad712db648a6c
# 1           1  38c5c2886f2aab75bb1ae3f79a3f300d
# 2           2  71303d7e93b399f5bcd537d124c0bcfa
# 3           3  cd3b8574c82b42fc8129f6d502690c3e
# 4           4  be5bc2f0da14d8071e2d45451ad119d9
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  86dc2ffce2dfff336de2f386a786e574    delivered               2016-09-15
# 1  6676a459c2b773481c9dacde3c44c680    delivered               2016-10-08
# 2  b106b360fe2ef8849fbbd056f777b4d5     canceled               2016-10-02
# 3  7812fcebfc5e8065d31e1bb5f0017dae    delivered               2016-10-03
# 4  7ec40b22510fdbea1b08921dd39e63d8    delivered               2016-10-03
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2016-09-15 12:16:38          2016-11-07 17:11:53
# 1  2016-10-08 09:10:46          2016-10-12 09:10:47
# 2  2016-10-06 15:50:56                          NaN
# 3  2016-10-04 10:19:23          2016-10-08 10:34:01
# 4  2016-10-06 16:03:44          2016-10-21 16:33:46
#
#   order_delivered_customer_date order_estimated_delivery_date  date_ordinal  \
# 0                    2016-11-09                    2016-10-04        736222
# 1                    2016-10-26                    2016-11-30        736245
# 2                    2016-11-09                    2016-10-25        736239
# 3                    2016-10-14                    2016-11-23        736240
# 4                    2016-10-27                    2016-11-07        736240
#
#    ...  product_category_name  product_name_lenght  \
# 0  ...           beleza_saude                 34.0
# 1  ...           beleza_saude                 34.0
# 2  ...                  bebes                 32.0
# 3  ...       fashion_calcados                 56.0
# 4  ...          esporte_lazer                 39.0
#
#    product_description_lenght product_photos_qty  product_weight_g  \
# 0                      1036.0                1.0            1000.0
# 1                      1036.0                1.0            1000.0
# 2                       561.0                1.0             500.0
# 3                       459.0                2.0            9000.0
# 4                       518.0                1.0             400.0
#
#   product_length_cm product_height_cm  product_width_cm  \
# 0              16.0              16.0              16.0
# 1              16.0              16.0              16.0
# 2              18.0              18.0              18.0
# 3              16.0               5.0              33.0
# 4              16.0              16.0              16.0
#
#    order_line_cube_in_ltr price_round
# 0                  12.288        40.0
# 1                   4.096        50.0
# 2                   5.832       100.0
# 3                   2.640        30.0
# 4                   4.096        20.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ---
# ## <a class="anchor" id="eda">II. Exploratory Data Analysis</a>

# %% [markdown]
# How many unique customers, SKUs and orders?

# %%
n_customers = df_orders_consolidated['customer_id'].nunique()
n_SKUs = df_orders_consolidated['product_id'].nunique()
n_orders = df_orders_consolidated['order_id'].nunique()
print('Unique customers: {}'.format(n_customers))
print('Unique SKUs: {}'.format(n_SKUs))
print('Unique orders: {}'.format(n_orders))
# Out:
# Unique customers: 98664
# Unique SKUs: 32949
# Unique orders: 98664

# %% [markdown]
# ---
# ## Order composition

# %%
df_order_class_comp = df_orders_consolidated.groupby([
    'order_id',
    'product_category_name'
    ]).agg({
        'product_id': 'count',
        'qty': 'sum',
        'price': 'sum',
        'order_line_cube_in_ltr': 'sum',
        'product_weight_g': 'sum',
        'estimated_duration': 'first',
        'shipping_duration': 'first',
        'shipping_time_delta': 'first',
        'order_purchase_timestamp': 'first'
        }).reset_index()

# %%
df_order_class_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98017 entries, 0 to 98016
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   order_id                  98017 non-null  object
#  1   product_category_name     98017 non-null  object
#  2   product_id                98017 non-null  int64
#  3   qty                       98017 non-null  int64
#  4   price                     98017 non-null  float64
#  5   order_line_cube_in_ltr    98017 non-null  float64
#  6   product_weight_g          98017 non-null  float64
#  7   estimated_duration        98017 non-null  int64
#  8   shipping_duration         98017 non-null  int64
#  9   shipping_time_delta       98017 non-null  int64
#  10  order_purchase_timestamp  98017 non-null  object
# dtypes: float64(3), int64(5), object(3)
# memory usage: 8.2+ MB

# %% [markdown]
# ### Order profile (units per line, units per order, lines per order)

# %%
df_upo_lpo = df_orders_consolidated\
    .groupby('order_id')\
    .agg({
        'qty': 'sum',
        'product_id': 'count'
        })\
    .reset_index()
df_upo_lpo.rename(columns = {
    'qty': 'units',
    'product_id': 'lines'
    }, inplace = True)

# %%
df_upo_lpo
# Out:
#                                order_id  units  lines
# 0      00010242fe8c5a6d1ba2dd792cb16214      1      1
# 1      00018f77f2f0320c557190d7a144bdd3      1      1
# 2      000229ec398224ef6ca0657da4fc703e      1      1
# 3      00024acbcdf0a6daa1e931b038114c75      1      1
# 4      00042b26cf59d7ce69dfabb4e55b4fd9      1      1
# ...                                 ...    ...    ...
# 98659  fffc94f6ce00a00581880bf54a75a037      1      1
# 98660  fffcd46ef2263f404302a634eb57f7eb      1      1
# 98661  fffce4705a9662cd70adb13d4a31832d      1      1
# 98662  fffe18544ffabc95dfada21779c9644f      1      1
# 98663  fffe41c64501cc87c801fd61db3f6244      1      1
#
# [98664 rows x 3 columns]

# %% [markdown]
# Plotting order profile charts

# %%
fig, ax = plt.subplots(3, 1, figsize = (15, 20))
sns.countplot(df_upo_lpo['units'], ax = ax[0])
sns.countplot(df_upo_lpo['lines'], ax = ax[1])
sns.countplot(df_order_class_comp['qty'], ax = ax[2])
ax[0].set(
    title = 'Units per order',
    xlabel = 'units per order',
    ylabel = 'Count'
    )
ax[1].set(
    title = 'Order lines per order',
    xlabel = 'order lines per order',
    ylabel = 'Count'
    )
ax[2].set(
    title = 'Units per order line',
    xlabel = 'units per order lines',
    ylabel = 'Count'
    );

# %% [markdown]
# This looks typical e-commerce: mostly SIO (single item orders); two-step-order picking is an option to deal with this (batch pick, sort, pack)

# %% [markdown]
# ### Generating pareto diagrams
# We will base them on different metrics:
# - units
# - lines
# - volume (cube)
#
# Step 1: Creating a SKU list with aggregated values

# %%
df_orders_consolidated.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'customer_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'date_ordinal', 'shipping_time_delta',
#        'shipping_duration', 'estimated_duration', 'product_id', 'qty',
#        'seller_id', 'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_line_cube_in_ltr', 'price_round'],
#       dtype='object')

# %%
df_SKUs = df_orders_consolidated\
    .groupby('product_id')\
    .agg({
        'qty': 'sum',
        'order_id': 'count',
        'order_line_cube_in_ltr': 'sum',
        'price': 'sum',
        'shipping_duration': 'mean'})

# %%
df_SKUs.rename(columns = {
        'qty': 'total_qty',
        'order_id': 'total_lines',
        'order_line_cube_in_ltr': 'total_cube',
        'shipping_duration': 'avg_ship_duration',
        'price': 'total_price'
        }, inplace = True)

# %%
# Adding counting column
df_SKUs['counter'] = 1

# %%
df_SKUs
# Out:
#                                   total_qty  total_lines  total_cube  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38          1            1       5.120
# 00088930e925c41fd95ebfe695fd2655          1            1      14.300
# 0009406fd7479715e4bef61dd91f2462          1            1      23.625
# 000b8f95fcb9e0096488278317764d19          2            2      10.944
# 000d9be29b5207b54e86aa1b1ac54872          1            1       3.630
# ...                                     ...          ...         ...
# fff6177642830a9a94a0f2cba5e476d1          2            2      31.500
# fff81cc3158d2725c0655ab9ba0f712c          1            1       2.816
# fff9553ac224cec9d15d49f5a263411f          1            1       2.288
# fffdb2d0ec8d6a61f0a0a0db3f25b441          5            5       4.160
# fffe9eeff12fcbd74a2f2b007dde0c58          1            1       7.568
#
#                                   total_price  avg_ship_duration  counter
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38       101.65               17.0        1
# 00088930e925c41fd95ebfe695fd2655       129.90               11.0        1
# 0009406fd7479715e4bef61dd91f2462       229.00               16.0        1
# 000b8f95fcb9e0096488278317764d19       117.80                6.5        1
# 000d9be29b5207b54e86aa1b1ac54872       199.00                7.0        1
# ...                                       ...                ...      ...
# fff6177642830a9a94a0f2cba5e476d1       229.98                9.0        1
# fff81cc3158d2725c0655ab9ba0f712c        90.00                2.0        1
# fff9553ac224cec9d15d49f5a263411f        32.00               10.0        1
# fffdb2d0ec8d6a61f0a0a0db3f25b441       169.95                6.6        1
# fffe9eeff12fcbd74a2f2b007dde0c58       249.99               23.0        1
#
# [32949 rows x 6 columns]

# %% [markdown]
# Need to sort by quantity, then add a cummulating percent counter for unit based pareto.

# %%
def classifier(num):
    if num < 5:
        v_class = 'A'
    elif num < 20:
        v_class = 'B'
    elif num < 50:
        v_class = 'C'
    else:
        v_class = 'D'
    return v_class

# %%
def pareto_izer(dat, col):
    '''A function which adds prepares and executes a pareto curve for a given feature
    The dataframe is sorted in descending order for the given feature
    
    Inputs:     data frame, feature (column)
    
    Outputs:    column with cumulated, sorted veature values
                Pareto chart'''
    
    dat.sort_values(by = col, ascending = False, inplace = True) # sort by the feature   
    dat['cum_' + col] = dat[col].cumsum()/dat[col].sum()*100 # add or re-assign column whith the cummulated sum
    df_SKUs['v_class_' + col] = dat['cum_' + col].map(classifier) # add or re-assign SKU velocity class (ABC)

    # Plotting the chart
    f, ax = plt.subplots(figsize = (15, 7))
    ax = sns.lineplot(x = dat['counter']\
        .cumsum()/dat['counter']\
        .sum()*100, data = dat, y = ('cum_' + col))
    ax = plt.title('Pareto chart of % {} over % SKUs'. format(col))
    ax = plt.xlabel('Percentage SKUs')
    ax = plt.ylabel('Percentage {}'.format(col))
    return ax

# %%
pareto_izer(df_SKUs, 'total_qty');

# %%
pareto_izer(df_SKUs, 'total_lines');

# %%
pareto_izer(df_SKUs, 'total_price');

# %%
pareto_izer(df_SKUs, 'total_cube');

# %% [markdown]
# That looks like a good result. While the pareto charts of the total quantity and lines are following a 70/20 trend, the total price and total cube show a 80/20 curve.

# %%
df_SKUs
# Out:
#                                   total_qty  total_lines  total_cube  \
# product_id
# 389d119b48cf3043d311335e499d9c6b        392          311   12763.520
# 99a4788cb24856965c36a24e339b6058        488          467    9760.000
# 422879e10f46682990de24d770e7f83d        484          352    9583.200
# aca2eb7d00ea1a7b8ebd4e68314663af        527          431    7905.000
# 368c6c730842d78016ad823897a372db        388          291    7682.400
# ...                                     ...          ...         ...
# 71225f49be70df4297892f6a5fa62171          1            1       0.352
# 2bc14ec16ec416f08e39fed48eda7f2d          1            1       0.352
# 5a2a2db3896d33beec6828b898812ad5          1            1       0.352
# 2f763ba79d9cd987b2034aac7ceffe06          1            1       0.288
# 106392145fca363410d287a815be6de4          1            1       0.168
#
#                                   total_price  avg_ship_duration  counter  \
# product_id
# 389d119b48cf3043d311335e499d9c6b     16981.49          15.926045        1
# 99a4788cb24856965c36a24e339b6058     41193.56          13.516060        1
# 422879e10f46682990de24d770e7f83d     19265.00          15.946023        1
# aca2eb7d00ea1a7b8ebd4e68314663af     30730.60          12.044084        1
# 368c6c730842d78016ad823897a372db     15776.30          15.384880        1
# ...                                       ...                ...      ...
# 71225f49be70df4297892f6a5fa62171        27.30          13.000000        1
# 2bc14ec16ec416f08e39fed48eda7f2d        34.30          14.000000        1
# 5a2a2db3896d33beec6828b898812ad5        27.30           5.000000        1
# 2f763ba79d9cd987b2034aac7ceffe06       469.00          20.000000        1
# 106392145fca363410d287a815be6de4       107.50           5.000000        1
#
#                                   cum_total_qty v_class_total_qty  \
# product_id
# 389d119b48cf3043d311335e499d9c6b       1.678695                 A
# 99a4788cb24856965c36a24e339b6058       0.901045                 A
# 422879e10f46682990de24d770e7f83d       1.330706                 A
# aca2eb7d00ea1a7b8ebd4e68314663af       0.467833                 A
# 368c6c730842d78016ad823897a372db       2.023134                 A
# ...                                         ...               ...
# 71225f49be70df4297892f6a5fa62171      98.945378                 D
# 2bc14ec16ec416f08e39fed48eda7f2d      90.375243                 D
# 5a2a2db3896d33beec6828b898812ad5      98.390547                 D
# 2f763ba79d9cd987b2034aac7ceffe06      90.845739                 D
# 106392145fca363410d287a815be6de4      92.723286                 D
#
#                                   cum_total_lines v_class_total_lines  \
# product_id
# 389d119b48cf3043d311335e499d9c6b         1.839449                   A
# 99a4788cb24856965c36a24e339b6058         0.455957                   A
# 422879e10f46682990de24d770e7f83d         1.220441                   A
# aca2eb7d00ea1a7b8ebd4e68314663af         0.876765                   A
# 368c6c730842d78016ad823897a372db         2.422331                   A
# ...                                           ...                 ...
# 71225f49be70df4297892f6a5fa62171        87.998672                   D
# 2bc14ec16ec416f08e39fed48eda7f2d        97.066060                   D
# 5a2a2db3896d33beec6828b898812ad5        85.897561                   D
# 2f763ba79d9cd987b2034aac7ceffe06        96.696999                   D
# 106392145fca363410d287a815be6de4        85.529476                   D
#
#                                   cum_total_price v_class_total_price  \
# product_id
# 389d119b48cf3043d311335e499d9c6b         7.317767                   B
# 99a4788cb24856965c36a24e339b6058         1.951712                   A
# 422879e10f46682990de24d770e7f83d         6.461199                   B
# aca2eb7d00ea1a7b8ebd4e68314663af         3.870010                   A
# 368c6c730842d78016ad823897a372db         7.572857                   B
# ...                                           ...                 ...
# 71225f49be70df4297892f6a5fa62171        99.578473                   D
# 2bc14ec16ec416f08e39fed48eda7f2d        99.279255                   D
# 5a2a2db3896d33beec6828b898812ad5        99.576116                   D
# 2f763ba79d9cd987b2034aac7ceffe06        71.261470                   D
# 106392145fca363410d287a815be6de4        93.876892                   D
#
#                                   cum_total_cube v_class_total_cube
# product_id
# 389d119b48cf3043d311335e499d9c6b        0.743309                  A
# 99a4788cb24856965c36a24e339b6058        1.311702                  A
# 422879e10f46682990de24d770e7f83d        1.869798                  A
# aca2eb7d00ea1a7b8ebd4e68314663af        2.330161                  A
# 368c6c730842d78016ad823897a372db        2.777561                  A
# ...                                          ...                ...
# 71225f49be70df4297892f6a5fa62171       99.999932                  D
# 2bc14ec16ec416f08e39fed48eda7f2d       99.999953                  D
# 5a2a2db3896d33beec6828b898812ad5       99.999973                  D
# 2f763ba79d9cd987b2034aac7ceffe06       99.999990                  D
# 106392145fca363410d287a815be6de4      100.000000                  D
#
# [32949 rows x 14 columns]

# %% [markdown]
# ### Adding XYZ profile

# %% [markdown]
# Creating a dataframe which counts the number of active days for each SKU

# %%
SKUs_active_days = df_orders_consolidated\
    .groupby(['order_purchase_timestamp', 'product_id'])\
    .agg({'order_id': 'count'})\
    .reset_index()

# %%
SKUs_active_days = SKUs_active_days.groupby('product_id')\
    .agg({'order_purchase_timestamp': 'count'})\
    .sort_values(by='order_purchase_timestamp', ascending = False)\
    .reset_index()

# %%
SKUs_active_days.rename(columns = {'order_purchase_timestamp': 'active_days'}, inplace = True)

# %%
SKUs_active_days.head()
# Out:
#                          product_id  active_days
# 0  99a4788cb24856965c36a24e339b6058          268
# 1  d1c427060a0f73f6b889a5c7c61f2ac4          202
# 2  422879e10f46682990de24d770e7f83d          196
# 3  2b4609f8948be18874494203496bc318          193
# 4  154e7e31ebfa092203795c972e5804a6          192

# %% [markdown]
# Adding the XYZ classification column

# %%
sample_timespan = df_orders_consolidated['order_purchase_timestamp'].max() - df_orders_consolidated['order_purchase_timestamp'].min()

# %%
def xyz_classifier(num):
    t_span = sample_timespan.days
    if num > (t_span * 2 / 3):
        activity_class = 'X'
    elif num > (t_span * 1 / 3):
        activity_class = 'Y'
    else:
        activity_class = 'Z'
        
    return activity_class

# %%
SKUs_active_days['XYZ_class'] = SKUs_active_days['active_days'].map(xyz_classifier)

# %%
SKUs_active_days
# Out:
#                              product_id  active_days XYZ_class
# 0      99a4788cb24856965c36a24e339b6058          268         Y
# 1      d1c427060a0f73f6b889a5c7c61f2ac4          202         Z
# 2      422879e10f46682990de24d770e7f83d          196         Z
# 3      2b4609f8948be18874494203496bc318          193         Z
# 4      154e7e31ebfa092203795c972e5804a6          192         Z
# ...                                 ...          ...       ...
# 32944  69ac97e466e0d1329784803bb0d3319e            1         Z
# 32945  69abb160096c6a83656bff3c715a7497            1         Z
# 32946  69ab89fdb9df3f93455a0c52d6e4e3f0            1         Z
# 32947  69a7ee112e7b63892ad5db80e4c3277f            1         Z
# 32948  fffe9eeff12fcbd74a2f2b007dde0c58            1         Z
#
# [32949 rows x 3 columns]

# %% [markdown]
# Merging SKUs_active_days to df_SKUs

# %%
df_SKUs = df_SKUs.merge(SKUs_active_days, on = 'product_id')

# %%
df_SKUs.columns
# Out:
# Index(['product_id', 'total_qty', 'total_lines', 'total_cube', 'total_price',
#        'avg_ship_duration', 'counter', 'cum_total_qty', 'v_class_total_qty',
#        'cum_total_lines', 'v_class_total_lines', 'cum_total_price',
#        'v_class_total_price', 'cum_total_cube', 'v_class_total_cube',
#        'active_days', 'XYZ_class'],
#       dtype='object')

# %% [markdown]
# Let's plot the XYZ diagram.

# %%
sns.catplot(data = df_SKUs, x = 'v_class_total_qty', y = 'cum_total_qty', kind = 'bar', aspect = 1, hue = 'XYZ_class')

# %%
df_SKUs['XYZ_class'].value_counts()
# Out:
# Z    32948
# Y        1
# Name: XYZ_class, dtype: int64

# %% [markdown]
# Almost all SKUs are Z class, which means they are sold very infrequently.

# %%
#sns.pairplot(df_SKUs)
